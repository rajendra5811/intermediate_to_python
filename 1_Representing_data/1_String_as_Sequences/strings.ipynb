# %%
s = 'Udacity'    
g='global'
n="""udacity is education 
platfrom"""
t=s.upper()
b=s.lower()
# Access an element by index, starting at position 0. concatinate
print(s[0]+s[1]+s[4])
print(g[0]+g[1])
# Access an element by a negative index, starting at the end.
print(s[-1]+s[-2]+s[-4]+s[-7])
print(g[-1]+g[-4])
print(t)
print(b)
print(n)
# Out:
# Udi
# gl
# ytcU
# lo
# UDACITY
# udacity
# udacity is education
# platfrom

# %%
print(s[0:2]) #slicing [a:b] a start b end
print(s[4:7])
print(s[1:5])
print(g[1:5])
# Out:
# Ud
# ity
# daci
# loba

# %%
print(s[1:5:2]) #step slicing [a:b:c] a start b end c increment
print(s[4::-2])
print(g[2::-1])
# Out:
# dc
# iaU
# olg

# %%
s = "SCHOOLED" #Which of the following will evaluate to the string "COLD"?
print(s[1::2])
print(s[1]+s[3]+s[5]+s[7])
print(s[1]+s[3]+s[-3]+s[-1])
print(s[::-1])
# Out:
# COLD
# COLD
# COLD
# DELOOHCS

# %%
n.split()
# Out:
# ['udacity', 'is', 'education', 'platfrom']

# %%
"-".join(["a", "b", "c"]) # - is separator
# Out:
# 'a-b-c'

# %%
"".join(["H", "i"])
# Out:
# 'Hi'
